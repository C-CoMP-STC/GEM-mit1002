# %%
import json

import cobra
from gem_utilities import curation

# %%
model = cobra.io.read_sbml_model("model.xml")

# %%
# Load the modelSEED databases and convert them to dictionaries
rxn_db = json.load(
    open("/Users/helenscott/Documents/PhD/Segre-lab/ModelSEEDDatabase/Biochemistry/reactions.json")
)
met_db = json.load(
    open("/Users/helenscott/Documents/PhD/Segre-lab/ModelSEEDDatabase/Biochemistry/compounds.json")
)

# Convert the ModelSEED databases to dictionaries for easy searching
template_rxn_db = {rxn["id"]: rxn for rxn in rxn_db if not rxn["is_obsolete"]}
template_met_db = {met["id"]: met for met in met_db if not met["is_obsolete"]}

# %%
model.metabolites.cpd00123_c0
# Out:
# <Metabolite cpd00123_c0 at 0x168fea650>

# %%
# Add a transport reaction for 3-methyl-2-oxobutanoate (cpd00123)
new_model = curation.add_ms_reaction_from_id(
    model, template_rxn_db, template_met_db, 'rxn09799'
    )

# %%
new_model.metabolites.cpd00123_c0
# Out:
# <Metabolite cpd00123_c0 at 0x30d020810>

# %%
new_model.metabolites.cpd00123_e0
# Out:
# <Metabolite cpd00123_e0 at 0x30da20e10>

# %%
# Save the new model
cobra.io.write_sbml_model(new_model, "model.xml")
